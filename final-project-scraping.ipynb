# %% [markdown]
# # Final Project Web Scraping

# %%
import pandas as pd
import re
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get("https://www.unegui.mn/kompyuter-busad/notebook/?condition=all")

# %%
soup = BeautifulSoup(response.content)

# %%
links = soup.find_all("a",{"class":"mask"})

# %%
links[0].get('href')
# Out:
# '/adv/7826537_asus-rog-gl752vw-16gb-ram-i7-6/'

# %%
urls = []
for link in links:
    url = link.get('href')
    full_url = "https://www.unegui.mn/" + url
    urls.append(full_url)

# %% [markdown]
# ## Scraping one listing

# %%
response = requests.get("https://www.unegui.mn/adv/6519285_msi-gf63-rtx-i5-11th-gen-fullbox/")

# %%
soup = BeautifulSoup(response.content)

# %%
page_content = soup.find_all("div",{"class":"js-description"})

# %%
page_content[0].get_text().replace('\n',' ')
# Out:
# ' -Сайн байна уу? Enjoy life by buying laptop 😄 Онлайн лизинг: Zeelme, Storepay, Lend, Sono, Pocket, khanbank  Brand : MSI Model: GF63 11Thin CPU : Core i5 11th gen RAM : 8GB HARD : 256GB SSD Graphics card : RTX3050 Display : 15.6 inch FHD 144Hz Software : 100% Usesage : NEW (ашигласан байдал) From : USA (order to online platform)  Таньд албан ёсны баталгаа 12 сар гаргаж өгнө Дагалдах хэрэгсэл: Цүнх, ориг цэнэглэгч, wireless mouse, keyboard хамгаалалтын хуулга, монгол үсэг ,pad  Анхаарал хандуулсанд баярлалаа. '

# %%
price0 = soup.find("div",{"class":"announcement-price__cost"}).get_text(strip=True).split(" ")

# %%
manufacturer = soup.find_all("span",{"itemprop":"name"})

# %%
manufacturer[3].get_text()
# Out:
# 'MSI'

# %%
screen = soup.find_all("a",{"class":"value-chars"})

# %%
screen[0].get_text(strip=True)
# Out:
# "15'' - 15,6''"

# %% [markdown]
# ## Scraping multiple listings

# %%
response_new = requests.get("https://www.unegui.mn/kompyuter-busad/notebook/?condition=new")

# %%
soup = BeautifulSoup(response_new.content)

# %%
links_new = soup.find_all("a",{"class":"mask"})

# %%
urls = []
condition = []

# %%
for link in links_new:
    url = link.get('href')
    full_url = "https://www.unegui.mn/" + url
    urls.append(full_url)
    condition.append("New")

# %%
response_used = requests.get("https://www.unegui.mn/kompyuter-busad/notebook/?condition=used")

# %%
soup = BeautifulSoup(response_used.content)

# %%
links_used = soup.find_all("a",{"class":"mask"})

# %%
for link in links_used:
    url = link.get('href')
    full_url = "https://www.unegui.mn/" + url
    urls.append(full_url)
    condition.append("Used")

# %%
description = []
manufacturer = []
price = []
screen = []
for url in urls:
    response = requests.get(url)
    soup = BeautifulSoup(response.content)
    page_content = soup.find_all("div",{"class":"js-description"})
    description.append(page_content[0].get_text().replace('\n',' '))
    
    price0 = soup.find("div",{"class":"announcement-price__cost"}).get_text(strip=True).split(" ")
    price.append(price0[0])
    
    manufacturer0 = soup.find_all("span",{"itemprop":"name"})
    manufacturer.append(manufacturer0[3].get_text())
    
    screen0 = soup.find_all("a",{"class":"value-chars"})
    screen.append(screen0[0].get_text())

# %%
description[10]
# Out:
# ' Америкаас ирсэн лацтай шинэ лаптопууд худалдаалж байна.   Macbook air M2 13 inch  Macbook air M2 15 inch  Macbook pro M2 13 inch '

# %%
price[10]
# Out:
# '3.85'

# %%
manufacturer[10]
# Out:
# 'Apple'

# %%
screen[10]
# Out:
# "13'' - 14''"

# %% [markdown]
# ## Multiple pages of listings

# %%
urls = []
condition = []

# %%
i = 1
n = int(input())
while i<=n:
    url = f"https://www.unegui.mn/kompyuter-busad/notebook/?page={i}&condition=new"
    response = requests.get(url)
    soup = BeautifulSoup(response.content)
    links = soup.find_all("a",{"class":"mask"})
    for link in links:
        url = link.get('href')
        full_url = "https://www.unegui.mn/" + url
        urls.append(full_url)
        condition.append("New")
    i = i + 1
# Out:
#  40

# %%
i = 1
n = int(input())
while i<=n:
    url = f"https://www.unegui.mn/kompyuter-busad/notebook/?page={i}&condition=used"
    response = requests.get(url)
    soup = BeautifulSoup(response.content)
    links = soup.find_all("a",{"class":"mask"})
    for link in links:
        url = link.get('href')
        full_url = "https://www.unegui.mn/" + url
        urls.append(full_url)
        condition.append("Used")
    i = i + 1
# Out:
#  40

# %%
len(urls)
# Out:
# 4800

# %%
description = []
manufacturer = []
price = []
screen = []
for url in urls:
    response = requests.get(url)
    soup = BeautifulSoup(response.content)
    page_content = soup.find_all("div",{"class":"js-description"})
    description.append(page_content[0].get_text().replace('\n',' '))
    
    price0 = soup.find("div",{"class":"announcement-price__cost"}).get_text(strip=True).split(" ")
    price.append(price0[0])
    
    manufacturer0 = soup.find_all("span",{"itemprop":"name"})
    manufacturer.append(manufacturer0[3].get_text())
    
    screen0 = soup.find_all("a",{"class":"value-chars"})
    screen.append(screen0[0].get_text(strip=True))

# %%
#     screen0 = soup.find_all("a",{"class":"value-chars"})
#     if screen0:
#         screen.append(screen0[0].get_text(strip=True))
#     else:
#         screen.append(None)

# %% [markdown]
# ## Making the DataFrame

# %%
storage_sizes = ['128GB', '256GB', '512GB', '1TB', '2TB', '4TB', '8TB', '128 GB', '256 GB', '512 GB', '1 TB', '2 TB', '4 TB', '8 TB']
ram_sizes = ['4GB', '8GB', '16GB', '32GB', '64GB', '4 GB', '8 GB', '16 GB', '32 GB', '64 GB']
processors = ['i3','i5', 'i7', 'i9', 'M2', 'M1', 'M3', 'Ryzen5', 'Ryzen5', 'Ryzen7', 'Ryzen9', 'Ryzen 9', 'Ryzen 7', 'Ryzen 5', 'Ryzen 3', 'Celeron']

# %%
graphics_cards = ['GTX 1650', 'GTX 1660', 'RTX 2060', 'RTX 2070', 'RTX 2080', 'RTX 2070', 'RTX 2070', 'RTX 2080', 'RTX 3050', 
                  'RTX 3050 Ti', 'RTX 3060', 'RTX 3070', 'RTX 3080 Ti', 'RTX 3080', 'AMD Radeon', 'Radeon AMD', 'Intel UHD', 'Apple']
for i in range(len(graphics_cards)):
    graphics_card = graphics_cards[i].replace(' ','')
    graphics_cards.append(graphics_card)

# %%
cpu_pattern = re.compile(r'CPU: ([^\-]+)')
ram_pattern = re.compile(r'RAM: ([^\-]+)')
storage_pattern = re.compile(r'HARD: ([^\-]+)')
display_pattern = re.compile(r'Display: ([^\-]+)')

# %%
gpu = []
storage = []
ram = []
processor = []

# %%
graphics_card_pattern = re.compile(fr'\b({"|".join(map(re.escape, graphics_cards))})\b', flags=re.IGNORECASE)
storage_size_pattern = re.compile(fr'\b({"|".join(map(re.escape, storage_sizes))})\b', flags=re.IGNORECASE)
ram_size_pattern = re.compile(fr'\b({"|".join(map(re.escape, ram_sizes))})\b', flags=re.IGNORECASE)
processor_pattern = re.compile(fr'\b({"|".join(map(re.escape, processors))})\b', flags=re.IGNORECASE)

# %%
for desc in description:
    graphics_card_match = graphics_card_pattern.search(desc)
    gpu.append(graphics_card_match.group(1) if graphics_card_match else None)

    storage_size_match = storage_size_pattern.search(desc)
    storage.append(storage_size_match.group(1) if storage_size_match else None)

    ram_size_match = ram_size_pattern.search(desc)
    ram.append(ram_size_match.group(1) if ram_size_match else None)

    processor_match = processor_pattern.search(desc)
    processor.append(processor_match.group(1) if processor_match else None)

# %%
df = pd.DataFrame({"manufacturer" : manufacturer, "condition" : condition, "price" : price, "screen size" : screen, "processor" : processor, "ram" : ram, "disk size" : storage, 
                   "graphics card" : gpu, "description" : description})

# %%
df.head(25)
# Out:
#          manufacturer condition         price    screen size processor    ram  \
# 0                  HP       New           3.8    16'' - 17''        i9   16GB
# 1                Asus       New           3.5  15'' - 15,6''        m2   32gb
# 2               Apple       New           3.3     13" хүртэл      None   None
# 3                Acer       New           2.2  15'' - 15,6''        i5    8GB
# 4                Asus       New           3.5    16'' - 17''      None   None
# 5                Asus       New          3.95    16'' - 17''        i9  16 GB
# 6                 MSI       New             3  15'' - 15,6''        i5    8GB
# 7   Microsoft Surface       New          4.19    13'' - 14''        i5    8GB
# 8               Apple       New          4.39    13'' - 14''        M2    8GB
# 9               Apple       New          3.39    13'' - 14''        M1    8GB
# 10              Apple       New          3.85    13'' - 14''        M2   None
# 11              Бусад       New           2.7    13'' - 14''      None   None
# 12               Asus       New           5.3    16'' - 17''        i7  16 GB
# 13               Asus       New          1.68  15'' - 15,6''        i7   16gb
# 14                 HP       New          1.85    13'' - 14''        i5    8GB
# 15             Lenovo       New          1.45  15'' - 15,6''        i5   16gb
# 16            Samsung       New  990,000₮1.05    13'' - 14''      None   None
# 17  Microsoft Surface       New           5.2    13'' - 14''        I7  16 GB
# 18              Apple       New             3     13" хүртэл        M1    8GB
# 19               Asus       New           3.7  15'' - 15,6''        i7   16GB
# 20               Asus       New           3.3    13'' - 14''        i7   16GB
# 21               Asus       New          3.65  15'' - 15,6''        i7   16GB
# 22               Asus       New          2.25  15'' - 15,6''        i5   16GB
# 23               Sony       New          2.25    13'' - 14''        i5    8GB
# 24               Dell       New           3.5    16'' - 17''        i5   None
#
#    disk size graphics card                                        description
# 0        1TB      RTX 3060   HP OMEN 16.1 Gaming laptop 165Hz  intel Core ...
# 1      512gb      Rtx 3070   Rtx 3070 32gb ddr4 3200mhz ram  512gb m2 ssd ...
# 2       None          None                                  Zarna asuudalgui
# 3      512GB       GTX1650   Acer A715-75G Gaming Laptop Хямд Зарна Үнэ то...
# 4       None          None   Japan laptopJapanaas avaad 6 sar bolj bga shi...
# 5        1TB       RTX3060   Asus Rog Zephyrus G16 / Gaming   Display : 16...
# 6      256GB       RTX3050   -Сайн байна уу? Enjoy life by buying laptop 😄...
# 7      256GB          None   💯 Баталгаа 12-24 сараар олгоно. 💯 - Хүргэлт ү...
# 8      256GB         Apple   💯 Баталгаа 12-24 сараар олгоно. 💯 - Хүргэлт ү...
# 9      256GB         Apple   💯 Баталгаа 12-24 сараар олгоно. 💯 - Хүргэлт ү...
# 10      None          None   Америкаас ирсэн лацтай шинэ лаптопууд худалда...
# 11      None          None                           Аваад хэрэглэж амжаагүй
# 12       1TB          None   Rogstrix G16 -i7-13 th New 2023/8 sar -16 GB ...
# 13     512gb          None   ✅CPU: Core i7-1165G7 (8cpus) 2.8ghz ✅Ram: 16g...
# 14     512GB          None   Цоо шинэ. Хайрцаг савтайгаа эзнээ хүлээж байн...
# 15     256gb          None   ✅CPU: Core i5-1135G7 /11-р үе/  ✅Ram: 16gb ✅H...
# 16      None          None   ✔️ Цоо шинэ задлаагүй  ✔️ Баталгаа 1жил  ✔️ Х...
# 17    256 GB          None   SURFACE PRO ЗАГВАРЫН ХАМГИЙН СҮҮЛД ГАРГАСАН  ...
# 18     256GB          None   Macbook air 13 inch M1 chip, 8GB, 256GB SSD P...
# 19     512GB     RTX3050ti   ✅Та онлайн лизингийн бүхий л төрлийн үйлчилгэ...
# 20       1TB          None   ✅Та онлайн лизингийн бүхий л төрлийн үйлчилгэ...
# 21     512GB       RTX3060   ✅Та онлайн лизингийн бүхий л төрлийн үйлчилгэ...
# 22     512GB          None   ✅Та онлайн лизингийн бүхий л төрлийн үйлчилгэ...
# 23     512GB          None   ✅Та онлайн лизингийн бүхий л төрлийн үйлчилгэ...
# 24    512 GB          None   i5-13th 512 GB 16 BG RTX-4050 6GB FHD 1920x10...

# %%
len(df)
# Out:
# 4800

# %% [markdown]
# ## Cleaning the Data

# %%
for i in range(len(df)):
    df['price'][i] = df['price'][i].split("₮")[0].replace(',','')

# %%
df['price'] = df['price'].astype(float)

# %%
for i in range(len(df)):
    if df['price'][i] < 10.00:
        df['price'][i] = df['price'][i] * 1_000_000
# Out:
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000
# <ipython-input-46-e268869f258e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][i] = df['price'][i] * 1_000_000

# %%
df['price'] = df['price'].astype(int)

# %%
df['price']
# Out:
# 0       3800000
# 1       3500000
# 2       3300000
# 3       2200000
# 4       3500000
#          ...
# 4795    3890000
# 4796    4690000
# 4797    1990000
# 4798     650000
# 4799     890000
# Name: price, Length: 4800, dtype: int32

# %%
for i in range(len(df)):
    df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# Out:
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')
# <ipython-input-49-d082850a92c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['manufacturer'][i] = df['manufacturer'][i].replace('Бусад','other')

# %%
df.isnull().sum()
# Out:
# manufacturer        0
# condition           0
# price               0
# screen size         0
# processor         517
# ram               384
# disk size         959
# graphics card    3600
# description         0
# dtype: int64

# %%
df['graphics card'].value_counts()
# Out:
# graphics card
# AMD Radeon    284
# Intel UHD     252
# Apple         147
# intel UHD     120
# AMD radeon     81
# AMD RADEON     71
# RTX 3050       39
# GTX1650        35
# APPLE          35
# GTX 1650       27
# INTEL UHD      22
# RTX 3060       19
# RTX 2060       12
# RTX3050         9
# RTX3060         6
# RTX 3070        6
# Amd radeon      3
# RTX 2070        3
# GTX1660         3
# GTX 1660        3
# RTX3070         3
# Amd Radeon      2
# apple           2
# RTX 2080        2
# RTX2060         2
# Rtx3050ti       2
# Intel uhd       1
# Rtx3050         1
# Rtx 3070        1
# amd radeon      1
# rtx3060         1
# rtx 3050        1
# RTX3050ti       1
# RTX3050Ti       1
# gtx1650         1
# intel uhd       1
# Name: count, dtype: int64

# %%
df['manufacturer'].value_counts()
# Out:
# manufacturer
# Dell                 1279
# Lenovo                908
# HP                    820
# Acer                  712
# Apple                 423
# Asus                  262
# Gateway               103
# other                  67
# Samsung                65
# Microsoft Surface      55
# MSI                    37
# Evoo                   31
# Toshiba                15
# Sony                   13
# LG                      8
# Haier                   1
# Compaq                  1
# Name: count, dtype: int64

# %%
df['price'].max()
# Out:
# 9000000

# %% [markdown]
# ## Finished DataFrame!

# %%
df.sample(25)
# Out:
#      manufacturer condition    price    screen size processor   ram disk size  \
# 328          Acer       New  2390000  15'' - 15,6''        i7   8gb    256 GB
# 3564         Acer      Used  1500000  15'' - 15,6''        i7   8GB       1TB
# 3815         Dell      Used  1750000     13" хүртэл        i7  16GB     256GB
# 1891           HP       New  2500000  15'' - 15,6''        i7   8GB     256GB
# 717        Lenovo       New  1390000  15'' - 15,6''        i3   4gb    128 GB
# 2889           HP      Used  1390000    13'' - 14''        i5  None     512GB
# 4747         Acer      Used  1290000  15'' - 15,6''        i5   4GB      None
# 2922         Dell      Used  1400000  15'' - 15,6''        i5  8 GB    512 GB
# 2534         Dell      Used  1800000  15'' - 15,6''        i5   8GB     256GB
# 4624      Samsung      Used  2200000    13'' - 14''        i5   8GB     256GB
# 4785        Apple      Used  1100000    13'' - 14''        I5  None      None
# 3296        Apple      Used  1590000    13'' - 14''        i5   8gb     256gb
# 647            HP       New  3300000  15'' - 15,6''   Ryzen 7   8GB       1TB
# 2010         Acer       New  1790000  15'' - 15,6''        i5   8GB    256 gb
# 655          Acer       New  1890000    13'' - 14''        i5   8GB     256gb
# 4660           HP      Used  1590000  15'' - 15,6''    Ryzen5   4GB     512GB
# 4504       Lenovo      Used  1390000    13'' - 14''        i5  16GB     256GB
# 3510      Samsung      Used   800000    16'' - 17''        i7   4gb       1tb
# 994         Apple       New  3750000    13'' - 14''        M2  None      None
# 356          Dell       New  2100000  15'' - 15,6''        i7  8 GB     512GB
# 159            HP       New  2500000  15'' - 15,6''      None  None      None
# 829          Acer       New  2390000  15'' - 15,6''        i5   8gb    512 GB
# 1947           HP       New  1490000  15'' - 15,6''        M2   8GB    128 GB
# 1801           HP       New  1190000    13'' - 14''        i3   4GB     128GB
# 327            HP       New  1350000  15'' - 15,6''      None  None      None
#
#      graphics card                                        description
# 328           None   Манай дэлгүүр Америк 👌👌стандартын зөөврийн 💻💻...
# 3564          None   ✅Та онлайн лизингийн бүхий л төрлийн үйлчилгэ...
# 3815          None   Сайн байна уу  Brand : Dell   Model : Latitud...
# 1891          None   -Сайн байна уу? Enjoy life by buying laptop 😄...
# 717      intel UHD   Манай дэлгүүр Америк 👌👌стандартын зөөврийн 💻💻...
# 2889          None   😁👍“NOTEBOOK SHOP”  Цэвэрхэн HP PROBOOK G4 i5-...
# 4747          None   💯 Баталгаа 12-24 сараар олгоно. 💯 - Хүргэлт ү...
# 2922          None   ✅ Сайн байна уу? 😊Манайд ШИНЭ БАРАА хямдралта...
# 2534          None   ✅Та онлайн лизингийн бүхий л төрлийн үйлчилгэ...
# 4624          None   ✅Та онлайн лизингийн бүхий л төрлийн үйлчилгэ...
# 4785          None            Маш цэвэрхэн Macbook air 2016 8/128 I5
# 3296          None   😁👍“NOTEBOOK SHOP”  Used маш цэвэрхэн Macbook ...
# 647       GTX 1660   ✅Та онлайн лизингийн бүхий л төрлийн үйлчилгэ...
# 2010     Intel UHD   Та хүссэн notebook-ээ #KhanBank -ны лизинг бо...
# 655           None   Та хүссэн notebook-ээ #KhanBank -ны лизинг бо...
# 4660    AMD Radeon   💯 Баталгаа 12-24 сараар олгоно. 💯 - Хүргэлт ү...
# 4504          None   😁👍“NOTEBOOK SHOP”  Авч явахад авсаархан жижиг...
# 3510          None   core i7 gen 3 gpu gt 650M 1gb ram 4gb hard ss...
# 994           None   USA irsen latstai hamgiin suuliin Macbook Air...
# 356     AMD Radeon   🇺🇸🇺🇸🇺🇸USA~с ирсэн 💯original, Оффис ба мэргэжл...
# 159           None   Манай дэлгүүр Америк 👌👌стандартын зөөврийн 💻💻...
# 829      Intel UHD   Манай дэлгүүр Америк 👌👌стандартын зөөврийн 💻💻...
# 1947    AMD Radeon   Манай дэлгүүр Америк 👌👌стандартын зөөврийн 💻💻...
# 1801          None   Манай дэлгүүр Америк 👌👌стандартын зөөврийн 💻💻...
# 327           None   Та хүссэн notebook-ээ #KhanBank -ны лизинг бо...

# %%
df.to_csv(r'C:\Users\user\Desktop\finaldf.csv', index=False)
